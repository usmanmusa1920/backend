# %%
from PIL import Image

img = Image.open("baby.jpg")
img.thumbnail((500, 500))

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x465>

# %%
import cv2

image = cv2.imread("baby.jpg")
grey_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

inverted = 255 - grey_image
blur = cv2.GaussianBlur(inverted, (21, 21), 0)
invertedblur = 255 - blur

sketch = cv2.divide(grey_image, invertedblur, scale=256.0)
cv2.imwrite("sketch.png", sketch)
# cv2.imshow("Image", sketch)
# Out:
# True

# %%
img = Image.open("sketch.png")
img.thumbnail((500, 500))

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=500x465>
