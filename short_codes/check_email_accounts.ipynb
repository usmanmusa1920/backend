# %%
# pip install holehe
import subprocess

def check_email_account(email):
    result = subprocess.run(
        ["holehe", email],
        capture_output = True,
        text = True
    )
    return result.stdout

# %%
print(check_email_account("python@gmail.com"))
# Out:
# Twitter : @palenath
# Github : https://github.com/megadose/holehe
# For BTC Donations : 1FHDM49QfZX6pJmhjLE5tB2K6CaTLMZpXZ
#
# **********************
#    python@gmail.com
# **********************
# [x] about.me
# [-] adobe.com
# [x] amazon.com
# [x] amocrm.com
# [+] any.do
# [-] archive.org
# [x] armurerie-auxerre.com
# [x] atlassian.com
# [x] axonaut.com
# [x] babeshows.co.uk
# [x] badeggsonline.com
# [x] bios-mods.com
# [x] biotechnologyforums.com
# [x] bitmoji.com
# [x] blablacar.com
# [x] blackworldforum.com
# [-] blip.fm
# [x] forum.blitzortung.org
# [x] bluegrassrivals.com
# [-] bodybuilding.com
# [x] buymeacoffee.com
# [x] discussion.cambridge-mt.com
# [x] caringbridge.org
# [x] chinaphonearena.com
# [x] clashfarmer.com
# [x] codecademy.com
# [x] forum.codeigniter.com
# [x] codepen.io
# [x] coroflot.com
# [x] cpaelites.com
# [x] cpahero.com
# [x] cracked.to
# [x] crevado.com
# [x] deliveroo.com
# [x] demonforums.net
# [x] devrant.com
# [x] diigo.com
# [-] discord.com
# ...
