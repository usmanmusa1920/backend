# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

k = np.sqrt([20,30,40,60])
k.reshape(4,1)
# Out:
# array([[4.47213595],
#        [5.47722558],
#        [6.32455532],
#        [7.74596669]])

# %%
test = np.array([4, 70, 8, 12, 30])
s = pd.Series(test, index=[1,7,8,9,5])
print(s)
plt.plot(range(5),s,range(5))
plt.draw()
# Out:
# 1     4
# 7    70
# 8     8
# 9    12
# 5    30
# dtype: int64

# %%
k = {
    'students':['Usman','Yusuf','Muhammad','Ahmad'],
    'lecturers':['Isma\'il', 'Saleh', 'Mamman', 'Aliyu'],
    'bool':[False,True,False,True],
    'university':['FUG', 'ABU', 'KASU', 'BUK'],
    'faculty':['science', 'education', 'humanity', 'social science'],
    'no':[100,34,5,80],
    'group':['A', 'B', 'C', 'D'],
    'house':['Red', 'Blue', 'Green', 'Yellow'],
}
s = pd.DataFrame(k, index=[i for i in range(1,5)])
# print(s)
s
# Out:
#    students lecturers   bool university         faculty   no group   house
# 1     Usman   Isma'il  False        FUG         science  100     A     Red
# 2     Yusuf     Saleh   True        ABU       education   34     B    Blue
# 3  Muhammad    Mamman  False       KASU        humanity    5     C   Green
# 4     Ahmad     Aliyu   True        BUK  social science   80     D  Yellow

# %%
s.students
# Out:
# 1       Usman
# 2       Yusuf
# 3    Muhammad
# 4       Ahmad
# Name: students, dtype: object

# %%
s.no
# Out:
# 1    100
# 2     34
# 3      5
# 4     80
# Name: no, dtype: int64

# %%
s.rank()
# Out:
#    students  lecturers  bool  university  faculty   no  group  house
# 1       3.0        2.0   1.5         3.0      3.0  4.0    1.0    3.0
# 2       4.0        4.0   3.5         1.0      1.0  2.0    2.0    1.0
# 3       2.0        3.0   1.5         4.0      2.0  1.0    3.0    2.0
# 4       1.0        1.0   3.5         2.0      4.0  3.0    4.0    4.0

# %%
s.iat[2,4]
# Out:
# 'humanity'

# %%
s.head(1)
# Out:
#   students lecturers   bool university  faculty   no group house
# 1    Usman   Isma'il  False        FUG  science  100     A   Red

# %%
# This is where cms start

df = pd.read_csv('survey_results_public.csv')
# df = pd.read_csv('survey_results_schema.csv')

# %%
df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
print(df.loc[2:2000,['Employment','Age']])
# Out:
#                                              Employment                Age
# 2                                    Student, full-time    18-24 years old
# 3                                    Employed full-time    35-44 years old
# 4     Independent contractor, freelancer, or self-em...    25-34 years old
# 5                                    Student, part-time    18-24 years old
# 6                                   I prefer not to say  Prefer not to say
# ...                                                 ...                ...
# 1996                                 Employed full-time    25-34 years old
# 1997  Independent contractor, freelancer, or self-em...    25-34 years old
# 1998                                 Student, full-time                NaN
# 1999                                 Employed full-time    35-44 years old
# 2000                                 Employed full-time    25-34 years old
#
# [1999 rows x 2 columns]

# %%
df.shape
# Out:
# (83439, 48)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83439 entries, 0 to 83438
# Data columns (total 48 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   ResponseId                    83439 non-null  int64
#  1   MainBranch                    83439 non-null  object
#  2   Employment                    83323 non-null  object
#  3   Country                       83439 non-null  object
#  4   US_State                      14920 non-null  object
#  5   UK_Country                    4418 non-null   object
#  6   EdLevel                       83126 non-null  object
#  7   Age1stCode                    83243 non-null  object
#  8   LearnCode                     82963 non-null  object
#  9   YearsCode                     81641 non-null  object
#  10  YearsCodePro                  61216 non-null  object
#  11  DevType                       66484 non-null  object
# ...

# %%
pd.set_option('display.max_columns', 48)

# %%
schema_df = pd.read_csv('survey_results_public.csv')

# %%
schema_df
# Out:
#        ResponseId                                         MainBranch  \
# 0               1                     I am a developer by profession
# 1               2             I am a student who is learning to code
# 2               3  I am not primarily a developer, but I write co...
# 3               4                     I am a developer by profession
# 4               5                     I am a developer by profession
# ...           ...                                                ...
# 83434       83435                     I am a developer by profession
# 83435       83436                     I am a developer by profession
# 83436       83437                     I am a developer by profession
# 83437       83438                     I am a developer by profession
# 83438       83439                     I am a developer by profession
#
#                                               Employment  \
# 0      Independent contractor, freelancer, or self-em...
# ...

# %%
# Thisis where cms end

# %%
# import pandas as pd
# import sqlite3

# create_table = """CREATE TABLE student(ID INTEGER, name VARCHAR(20))"""

# executesql = sqlite3.connect(':momery')
# executesql.execute(create_table)
# executesql.commit()
